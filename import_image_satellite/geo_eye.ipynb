# %%
import skimage.io as io
import skimage.viewer as viewer
import matplotlib.pyplot as plt
import numpy as np

# %%
geo = io.imread('E:/Company/KAVOSHGARAN/Virtual Irrigation/Image/Geo-Eye/geoeye.tif')

# %%
geo.dtype
# Out:
# dtype('uint16')

# %%
#change to array
arr_geo= np.array(geo).astype(float)

# %%
arr_geo.dtype
# Out:
# dtype('float64')

# %%
#normalization
norm_geo = (geo-np.min(geo))/(np.max(geo)-np.min(geo))

# %%
blue = norm_geo[:,:,0]
red = norm_geo[:,:,1]
green = norm_geo[:,:,2]

# %%
plt.figure(figsize=(20, 20))
plt.imshow(blue)
plt.title("GEO IMAGE", fontsize=20)
plt.axis('off')
plt.savefig("GEO.png")
plt.show()
